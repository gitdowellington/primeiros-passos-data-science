# %%
import pandas as pd
baseTMDB = pd.read_csv("https://raw.githubusercontent.com/gitdowellington/primeiros-passos-data-science/refs/heads/main/1.analise-exploratoria/base-dados/tmdb_5000_movies.csv")

# %%
linguagens_nao_inglesa = baseTMDB.query("original_language != 'en'")["original_language"].value_counts()

# %%
import seaborn as sns

sns.countplot(data = baseTMDB.query("original_language != 'en'"), x = 'original_language')
# Out:
# <Axes: xlabel='original_language', ylabel='count'>

# %%
sns.countplot(data = baseTMDB.query("original_language != 'en'"),
               x = 'original_language',
               order = linguagens_nao_inglesa.index)
# Out:
# <Axes: xlabel='original_language', ylabel='count'>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize= (10,5))
sns.countplot(data = baseTMDB.query("original_language != 'en'"),
               x = 'original_language',
               order = linguagens_nao_inglesa.index,
               palette = "mako",
               hue = "original_language",
               hue_order = linguagens_nao_inglesa.index,
               stat="percent"
              )
plt.title("Distribuição de linguagem dos Filmes (excelo lingua inglesa)")
# Out:
# Text(0.5, 1.0, 'Distribuição de linguagem dos Filmes (excelo lingua inglesa)')
